# %% [markdown]
# # Часть 1
#
# ## 1. Решить систему уравнений методом Гаусса:
#
# $\begin{cases}
# x_{1}+x_{2}-x_{3}-2x_{4}=0, \\
# 2x_{1}+x_{2}-x_{3}+x_{4}=-2, \\
# x_{1}+x_{2}-3x_{3}+x_{4}=4.
# \end{cases}$
#
# Запишем в матричном виде и решим методом Гаусса:
#
# $\begin{pmatrix}
# \left.\begin{matrix}
# 1 & 1 & -1 & -2\\
# 2 & 1 & -1 & 1 \\
# 1 & 1 & -3 & 1
# \end{matrix}\right|
# \begin{matrix}
# 0, \\
# -2, \\
# 4
# \end{matrix}
# \end{pmatrix}$
#
# Умножим 1-ю строку на (2). Умножим 2-ю строку на (-1). Добавим 2-ю строку к 1-й:
#
# $\begin{pmatrix}
# \left.\begin{matrix}
# 0 & 1 & -1 & -5\\
# 2 & 1 & -1 & 1 \\
# 1 & 1 & -3 & 1
# \end{matrix}\right|
# \begin{matrix}
# 2, \\
# -2, \\
# 4
# \end{matrix}
# \end{pmatrix}$
#
# Умножим 3-ю строку на (-2). Добавим 3-ю строку к 2-й:
#
# $\begin{pmatrix}
# \left.\begin{matrix}
# 0 & 1 & -1 & -5\\
# 0 & -1 & 5 & -1 \\
# 1 & 1 & -3 & 1
# \end{matrix}\right|
# \begin{matrix}
# 2, \\
# -10, \\
# 4
# \end{matrix}
# \end{pmatrix}$
#
# Добавим 2-ю строку к 1-й:
#
# $\begin{pmatrix}
# \left.\begin{matrix}
# 0 & 0 & 4 & -6\\
# 0 & -1 & 5 & -1 \\
# 1 & 1 & -3 & 1
# \end{matrix}\right|
# \begin{matrix}
# -8, \\
# -10, \\
# 4
# \end{matrix}
# \end{pmatrix}$
#
# $ x_3 = [-8 - ( - 6x_4)]/4 $
#
# $ x_2 = [-10 - (5x_3 - x_4)]/(-1) $
#
# $ x_1 = [4 - (x_2 - 3x_3 + x_4)]/1 $
#
#
# Пусть $ x_4 = 0 $
#
# $ x_3 = \frac{-8}{4} = -2 $
#
# $ x_2 = \frac{-10-5(-2)-(-1)}{-1} = 0 $
#
# $ x_1 = \frac{4-180-(-3)(-2)-1}{1} = -2 $

# %% [markdown]
# ## 2. Проверить на совместность и выяснить, сколько решений будет иметь система линейных уравнений:
#
#    а) $\begin{cases}
# 3x_{1}-x_{2}+x_{3}=4, \\
# 2x_{1}-5x_{2}-3x_{3}=-17, \\
# x_{1}+x_{2}-x_{3}=0;
# \end{cases}$
#
# Умножим 2-ю строку на (k = -1 / 2 = -1/2) и добавим к 3-й:
#
# $\begin{pmatrix}
# 3 & -1 & 1 & 4\\
# 2 & -5 & -3 & -17 \\
# 0 & \frac{7}{2} & \frac{1}{2} & \frac{13}{2}
# \end{pmatrix}$
#
# Умножим 1-ю строку на (k = -2 / 3 = -2/3) и добавим к 2-й:
#
# $\begin{pmatrix}
# 3 & -1 & 1 & 4\\
# 0 & -\frac{13}{3} & -\frac{11}{3} & -\frac{59}{3} \\
# 0 & \frac{7}{2} & -\frac{1}{2} & \frac{17}{2}
# \end{pmatrix}$
#
# Умножим 2-ю строку на (k = 7/2 / 13/3 = 21/26) и добавим к 3-й:
#
# $\begin{pmatrix}
# 3 & -1 & 1 & 4\\
# 0 & -\frac{13}{3} & -\frac{11}{3} & -\frac{59}{3} \\
# 0 & 0 & -\frac{32}{13} & -\frac{96}{13}
# \end{pmatrix}$
#
# Получим единицы на главной диагонали.
#
# $\begin{pmatrix}
# 1 & -\frac{1}{3} & \frac{1}{3} & \frac{4}{3}\\
# 0 & 1 & \frac{11}{13} & \frac{59}{13} \\
# 0 & 0 & 1 & 3
# \end{pmatrix}$
#
# Rang A=rang(A|B) => система совместная и определенная
# ___
#    б) $\begin{cases}
# 2x_{1}-4x_{2}+6x_{3}=1, \\
# x_{1}-2x_{2}+3x_{3}=-2, \\
# 3x_{1}-6x_{2}+9x_{3}=5;
# \end{cases}$
#
#
# $\begin{pmatrix}
# 3 & -6 & 9 & 5\\
# 2 & -4 & 6 & 1 \\
# 1 & -2 & 3 & -2
# \end{pmatrix}$
#
# Умножим 2-ю строку на (k = -1 / 2 = -1/2) и добавим к 3-й:
#
# $\begin{pmatrix}
# 3 & -6 & 9 & 5\\
# 2 & -4 & 6 & 1 \\
# 0 & 0 & 0 & -\frac{5}{2}
# \end{pmatrix}$
#
# Умножим 1-ю строку на (k = -2 / 3 = -2/3) и добавим к 2-й:
#
# $\begin{pmatrix}
# 3 & -6 & 9 & 5\\
# 0 & 0 & 0 & -\frac{7}{3} \\
# 0 & 0 & 0 & -\frac{5}{2}
# \end{pmatrix}$
#
# Добавим 3-ю строку к 2-й:
#
# $\begin{pmatrix}
# 3 & -6 & 9 & 5\\
# 0 & 0 & 0 & -\frac{7}{3} \\
# 0 & 0 & 0 & -\frac{29}{6}
# \end{pmatrix}$
#
# Получим единицы на главной диагонали.
#
# $\begin{pmatrix}
# 1 & -2 & 3 & \frac{5}{3}\\
# 0 & 0 & 0 & -\frac{7}{3} \\
# 0 & 0 & 0 & -\frac{29}{6}
# \end{pmatrix}$
#
# Rang A != rang(A|B) => система несовместна
#
# ___
#    в) $\begin{cases}
# x_{1}+2x_{2}+5x_{3}=4, \\
# 3x_{1}+x_{2}-8x_{3}=-2.
# \end{cases}$
#
# Умножим 1-ю строку на (k = -3 / 1 = -3) и добавим к 2-й:
#
# $\begin{pmatrix}
# 1 & 2 & 5 & 4\\
# 0 & -5 & -23 & -14
# \end{pmatrix}$
#
# Получим единицы на главной диагонали
#
# $\begin{pmatrix}
# 1 & 2 & 5 & 4\\
# 0 & -5 & -23 & -14
# \end{pmatrix}$
#
# A = rang(A|B) => система совместна и неопределена

# %% [markdown]
# ## 3. Проверить на совместность и выяснить, сколько решений будет иметь система линейных уравнений, заданная расширенной матрицей
#
# $\tilde{A}=\begin{pmatrix}
# \left.\begin{matrix}
# 1 & 3 & -2 & 4\\
# 0 & 5 & 0 & 1\\
# 0 & 0 & 3 & 0\\
# 0 & 0 & 0 & 2
# \end{matrix}\right|
# \begin{matrix}
# 3\\
# 2\\
# 4\\
# 1
# \end{matrix}
# \end{pmatrix}.$
#
#
# A = rang(A|B) => система совместна и неопределена

# %% [markdown]
# ## 4. Дана система линейных уравнений, заданная расширенной матрицей
#
# $\tilde{A}=\begin{pmatrix}
# \left.\begin{matrix}
# 1 & 2 & 3\\
# 4 & 5 & 6\\
# 7 & 8 & 9
# \end{matrix}\right|
# \begin{matrix}
# a\\
# b\\
# c
# \end{matrix}
# \end{pmatrix}.$
#
# Найти соотношение между параметрами $a$, $b$ и $c$, при которых система является несовместной.
#
# 1-ю строку умножим на 2 и вычтем из 2-й строки
#
# 1-ю строку умножим на 3 и вычтем из 3-й строки
#
# $\begin{pmatrix}
# \left.\begin{matrix}
# 1 & 2 & 3\\
# 2 & 1 & 0\\
# 4 & 2 & 0
# \end{matrix}\right|
# \begin{matrix}
# a\\
# b - 2a\\
# c - 3a
# \end{matrix}
# \end{pmatrix}.$
#
# 2-ю строку множим на 2 вычтем из 3 строки
#
# $\begin{pmatrix}
# \left.\begin{matrix}
# 1 & 2 & 3\\
# 2 & 1 & 0\\
# 0 & 0 & 0
# \end{matrix}\right|
# \begin{matrix}
# a\\
# b - 2a\\
# 2b - c - a
# \end{matrix}
# \end{pmatrix}.$
#
# Если 2b-c-a!=0 => система несовместна

# %% [markdown]
# # Часть 2
#
# ## 1. Решить систему уравнений методом Крамера:
#
#    а) $\begin{cases}
# x_{1}-2x_{2}=1 \\
# 3x_{1}-4x_{2}=7
# \end{cases}$
#
#
# $ det =  (1*(-4)-3*(-2)) = 2 $
#
# Заменим 1-й столбец матрицы А на вектор результата В.
#
# $\begin{vmatrix}
# 1 & -2 \\
# 7 & -4
# \end{vmatrix}$
#
# Найдем определитель полученной матрицы
#
# $ det_1 = 10 $
#
# $ x_1 = \frac{10}{2} = 5 $
#
# Заменим 2-й столбец матрицы А на вектор результата В.
#
# $\begin{vmatrix}
# 1 & 1 \\
# 3 & 7
# \end{vmatrix}$
#
# Найдем определитель полученной матрицы.
#
# $ det_2 = 4 $
#
# $ x_2 = 2 $
#
# ___
#
#    б) $\begin{cases}
# 2x_{1}-x_{2}+5x_{3}=10 \\
# x_{1}+x_{2}-3x_{3}=-2 \\
# 2x_{1}+4x_{2}+x_{3}=1
# \end{cases}$
#
# $ det = 50 $
#
# Заменим 1-й столбец матрицы А на вектор результата В.
#
# $\begin{vmatrix}
# 10 & -2 & 5 \\
# -2 & 1 & -3
# 1 & 4 & 1
# \end{vmatrix}$
#
# $ det_1 = 87 $
#
# $ x_1 = 1.74 $
#
# Заменим 2-й столбец матрицы А на вектор результата В.
#
# $\begin{vmatrix}
# 2 & 10 & 5 \\
# 1 & -2 & -3
# 2 & 1 & 1
# \end{vmatrix}$
#
# $ det_2 = -43 $
#
# $ x_2 = -0.86 $
#
# Заменим 3-й столбец матрицы А на вектор результата В.
#
# $\begin{vmatrix}
# 2 & -2 & 10 \\
# 1 & 1 & -2 \\
# 2 & 4 & 1
# \end{vmatrix}$
#
# $ det_3 = 48 $
#
# $ x_3 = 0.96 $

# %% [markdown]
# ## 2* Найти $L$-матрицу $LU$-разложения для матрицы коэффициентов:
#
#    а)$\begin{pmatrix}
# 1 & 2 & 4 \\
# 2 & 9 & 12 \\
# 3 & 26 & 30
# \end{pmatrix}$
#
# Умножим 1-ю строку на 2 и вычтем из 2 строки
#
# U-матрица
#
# $\begin{pmatrix}
# 1 & 2 & 4\\
# 0 & 5 & 4\\
# 3 & 26 & 30
# \end{pmatrix}$
#
# L-матрица
#
# $\begin{pmatrix}
# 1 & 0 & 0\\
# 2 & 1 & 0\\
# l_{31} & l_{32} & 1
# \end{pmatrix}$
#
#
# Умножим 1-ю строку на 3 и вычтем из 3 строки
#
# U-матрица
#
# $\begin{pmatrix}
# 1 & 2 & 4\\
# 0 & 5 & 4\\
# 0 & 20 & 18
# \end{pmatrix}$
#
# L-матрица
#
# $\begin{pmatrix}
# 1 & 0 & 0\\
# 2 & 1 & 0\\
# 3 & l_{32} & 1
# \end{pmatrix}$
#
# Умножим 2-ю строку на 4 и вычтем из 3:
#
# U-матрица
#
# $\begin{pmatrix}
# 1 & 2 & 4\\
# 0 & 5 & 4\\
# 0 & 0 & 2
# \end{pmatrix}$
#
# L-матрица
#
# $\begin{pmatrix}
# 1 & 0 & 0\\
# 2 & 1 & 0\\
# 3 & 4 & 1
# \end{pmatrix}$
#
# ___
#
#    б)$\begin{pmatrix}
# 1 & 1 & 2 & 4\\
# 2 & 5 & 8 & 9\\
# 3 & 18 & 29 & 18\\
# 4 & 22 & 53 & 33
# \end{pmatrix}$
#
# Умножим 1-ю строку на 2 и вычтем из 2 строки
#
# U - матрица
#
# $\begin{pmatrix}
# 1 & 1 & 2 & 4\\
# 0 & 3 & 4 & 1\\
# 3 & 18 & 29 & 18\\
# 4 & 22 & 53 & 33
# \end{pmatrix}$
#
# L - матрица
#
# $\begin{pmatrix}
# 1 & 0 & 0 & 0\\
# 2 & 1 & 0 & 0\\
# 3 & l_{32} & 1 & 0\\
# 4 & l_{42} & l_{43} & 1
# \end{pmatrix}$
#
#
# Умножим 2-ю строку на 5 и вычтем из 3 строки
#
# U - матрица
#
# $\begin{pmatrix}
# 1 & 1 & 2 & 4\\
# 0 & 3 & 4 & 1\\
# 0 & 0 & 3 & 1\\
# 0 & 18 & 45 & 17
# \end{pmatrix}$
#
# L - матрица
#
# $\begin{pmatrix}
# 1 & 0 & 0 & 0\\
# 2 & 1 & 0 & 0\\
# 3 & 5 & 1 & 0\\
# 4 & l_{42} & l_{43} & 1
# \end{pmatrix}$
#
# Умножим 2-ю строку на 6 и вычтем из 4 строки:
#
# $\begin{pmatrix}
# 1 & 1 & 2 & 4\\
# 0 & 3 & 4 & 1\\
# 0 & 0 & 3 & 1\\
# 0 & 0 & 21 & 11
# \end{pmatrix}$
#
# L - матрица
#
# $\begin{pmatrix}
# 1 & 0 & 0 & 0\\
# 2 & 1 & 0 & 0\\
# 3 & 5 & 1 & 0\\
# 4 & 6 & l_{43} & 1
# \end{pmatrix}$
#
#
# Умножим 3-ю строку на 7 и вычтем из 4 строки:
#
# $\begin{pmatrix}
# 1 & 1 & 2 & 4\\
# 0 & 3 & 4 & 1\\
# 0 & 0 & 3 & 1\\
# 0 & 0 & 0 & 4
# \end{pmatrix}$
#
# L - матрица
#
# $\begin{pmatrix}
# 1 & 0 & 0 & 0\\
# 2 & 1 & 0 & 0\\
# 3 & 5 & 1 & 0\\
# 4 & 6 & 7 & 1
# \end{pmatrix}$

# %% [markdown]
# ## 3* Решить систему линейных уравнений методом $LU$-разложения
#
# $\begin{cases}
# 2x_{1}+x_{2}+3x_{3}=1 \\
# 11x_{1}+7x_{2}+5x_{3}=-6 \\
# 9x_{1}+8x_{2}+4x_{3}=-5
# \end{cases}$
#
# Представим A в виде: A=BC
#
# $ b_{11}=2 $
#
# $ c_{11}=2/2=1 $
#
# $ c_{12}=1/2=0.5 $
#
# $ c_{13}=3/2=1.5 $
#
# $ b_{21}=11 $
#
# $ b_{22}=7 - (11*0.5)=1.5 $
#
# $ c_{22}=1.5/1.5=1 $
#
# $ c_{23}=-11.5/1.5=-7.667 $
#
# $ b_{31}=9 $
#
# $ b_{32}=8 - (9*0.5)=3.5 $
#
# $ b_{33}=4 - (9*1.5 + 3.5*-7.67)=17.33 $
#
# $ c_{33}=17.333/17.333=1 $
#
# B = $\begin{pmatrix}
# 2 & 0 & 0\\
# 11 & 1.5 & 0\\
# 9 & 3.5 & 17.333
# \end{pmatrix}$
#
# C = $\begin{pmatrix}
# 1 & 0.5 & 1.5\\
# 0 & 1 & -7.667\\
# 0 & 0 & 1
# \end{pmatrix}$
#
# Вычисляем значения $ y_i $
#
# $ y_1 = 1/2 = 0.5 $
#
# $ y_2 = (-6 - 11 * 0.5 )/1.5 = -7.67 $
#
# $ y_3 = (-5 - 9 * 0.5 + 3.5 * (-7.67) )/17.33 = 1 $
#
# Вычисляем значения $ x_i $
#
# $ x_3 = y3 = 1 $
#
# $ x_2 = -7.67 - (-7.67 * 1 ) = 0 $
#
# $ x_1 = 0.5 - (0.5 * 0 + 1.5 * 1 ) = -1 $
