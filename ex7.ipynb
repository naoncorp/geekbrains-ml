# %% [markdown]
# # Урок 7
#
# Найти длину 𝑥 и ширину 𝑦 прямоугольника при заданном периметре 𝑃=144 cм, при которых данный прямоугольник имеет наибольшую площадь 𝑆.
#
# Ну на Python-е я вроде нашел значения переменных, но полагаю, это не то, что требовалось по задаче :( подумаю еще.
#
# $ \large { p = 2(x+y) } $
#
# $ \large{ s = x*y } $
#
# $ \large { 144 = 2(x+y)} $
#
# $ \large { 72 = x+y } $
#
# $ \large { 72 / 2 = 36 } $

# %%
rg = range(1, 37)
v = []
res = []

for x in rg:
    for y in reversed(rg):
        v.append({x, y})
        res.append(x*y)
    
#print(res)
print(max(res))
#print(v)
print(v[res.index(max(res))])

# %% [markdown]
# **Найти экстремумы функции**
#
# ___
#
# $ \large{ y = |2x| } $
#
# $ \large{ \frac{d}{dx}|2x| = 2sign(x) } $
#
# $ \large{ 2sign(x) = 0 } $
#
# $ \large{ X_1=0 } $
#
# Экстремумы в точках (0,0)

# %% [markdown]
# ___
#
# $ \large{ y = x^3 } $
#
# $ \large{ \frac{d}{dx}x^3 = 3x^2 } $
#
# $ \large{ 3x^2 = 0 } $
#
# $ \large{ X_1=0 } $
#
# Экстремумы в точках (0,0)

# %% [markdown]
# ___
#
# $ \large{ y = e^{3x} } $
#
# $ \large{ \frac{d}{dx}e^{3x} = 3e^{3x} } $
#
# Нет корней? Нет экстремумов

# %% [markdown]
# ___
#
# $ \large{ y = x^3-5x } $
#
# $ \large{ \frac{d}{dx}x^3-5x = 3x^2-5 } $
#
# $ \large{ 3x^2-5 = 0 } $
#
# $ \large{ x_1= -\frac{\sqrt{15}}{3}, x_2 = \frac{\sqrt{15}}{3} } $
#
# Экстремумы в точках $ \large{(-\frac{\sqrt{15}}{3},\frac{\sqrt{15}}{3})} $
